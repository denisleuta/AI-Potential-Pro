# %%
import pandas as pd

df = pd.read_excel('new.xlsx')
df1 = pd.read_excel('games2024.xlsx')

# %%
df1
# Out:
#                        Турнир                   ИгрокФИО Амплуа  \
# 0       Молодежное первенство  Алферов Иван Владимирович     AM
# 1       Молодежное первенство  Алферов Иван Владимирович     AM
# 2       Молодежное первенство  Алферов Иван Владимирович     AM
# 3       Молодежное первенство  Алферов Иван Владимирович     AM
# 4       Молодежное первенство  Алферов Иван Владимирович     AM
# ...                       ...                        ...    ...
# 853905                  ЮФЛ-3           Гришанов Дмитрий     ST
# 853906                  ЮФЛ-3           Гришанов Дмитрий     ST
# 853907                  ЮФЛ-3           Гришанов Дмитрий     ST
# 853908                  ЮФЛ-3           Гришанов Дмитрий     ST
# 853909                  ЮФЛ-3           Гришанов Дмитрий     ST
#
#                     Команда                                              Матч  \
# 0                    Урал-М                Урал-М 2 : 3 Динамо-М (08.03.2024)
# ...

# %%
df1['КоличествоДействий'] = pd.to_numeric(df1['КоличествоДействий'], errors='coerce')

# %%
# Общее количество действий
total_actions = df['КоличествоДействий'].sum()
total_actions1 = df1['КоличествоДействий'].sum()

# Количество уникальных игроков
unique_players = df['ИгрокФИО'].nunique()
unique_players1 = df1['ИгрокФИО'].nunique()

# Количество уникальных матчей  
unique_matches = df['Матч'].nunique()
unique_matches1 = df1['Матч'].nunique()

print(f"Общее количество действий 2025: {total_actions}")
print(f"Уникальных игроков 2025: {unique_players}")
print(f"Уникальных матчей 2025: {unique_matches}")

print(f"Общее количество действий 2024: {total_actions1}")
print(f"Уникальных игроков 2024: {unique_players1}")
print(f"Уникальных матчей 2024: {unique_matches1}")
# Out:
# Общее количество действий 2025: 1729353
# Уникальных игроков 2025: 1676
# Уникальных матчей 2025: 744
# Общее количество действий 2024: 2599046.0
# Уникальных игроков 2024: 2016
# Уникальных матчей 2024: 1196
